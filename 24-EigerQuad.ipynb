# %%
from helpers import nb_aare_version
nb_aare_version()

#Our normal python imports
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np


#Directly import what we need from aare
from aare import RawFile

path = Path('/mnt/sls_det_storage/eiger_data/2023/W13_230320')
fname = path/'W13_vrpreampscan_m21C_300V_800eV_vthre2000_master_0.json'

with RawFile(fname) as f:
    header, data  = f.read()

fig, ax = plt.subplots()
im  = ax.imshow(data[20])
im.set_clim(0,1)
# Out:
# Example run on: **2025-06-23 12:29** with aare: **dev**
